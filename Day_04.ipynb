# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreemaee21/fmmlAssignments/blob/main/Day_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_list = [ 1, 6, 4.4, 5, 6]

# %%
plt.xlabel('Independent variable')
plt.ylabel('Dependent Variable')
plt.subplot(1, 2, 1)
plt.plot(np.array([3.5, 4, 5, 10, 11]), label="weight of child")
plt.legend()
plt.xlabel('Independent variable')
plt.ylabel('Dependent Variable')
plt.subplot(1, 2, 2)
plt.plot(np.array([1, 2, 3.5, 6, 5]), label="age of child")
plt.legend()

# %%
type(data_list[0])
# Out:
# int

# %%
plt.plot(data_list)

# %%
some_data = np.random.normal(0, 2, size=500)

# %%
sorted_some_data = np.sort(some_data)
np.max(sorted_some_data)
# Out:
# 6.303655200783021

# %%
#some_data = np.sort(some_data)
plt.xlabel('independent variable')
plt.ylabel('dependent variable')
plt.subplot(2, 1, 1)
noise = np.random.normal(0, 1, 500 )
noisy_data = sorted_some_data+noise
plt.plot(noisy_data, label='original')
plt.legend()
plt.subplot(2, 1, 2)
plt.xlabel('independent variable')
plt.ylabel('dependent variable')
plt.plot((noisy_data - np.min(noisy_data))/(np.max(noisy_data) - np.min(noisy_data)), label='normalised')
plt.legend()
